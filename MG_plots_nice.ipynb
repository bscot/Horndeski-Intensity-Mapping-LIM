# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
k = np.load('k_eff.npy')

# %%
cd Pk_from_hi_class/
# Out:
# [Errno 2] No such file or directory: 'Pk_from_hi_class/'
# /Users/bryan/Desktop/Research Summer 2020/Pk_from_hi_class

# %%
# load values for P(k) at z = 0.5
fiducial_05 = np.load('LCDM_Pk_0.5.npy')
MG_best_fit_05 = np.load('mg_Pk_0.5.npy')

# Varying x_b, x_m = 0.2, z = 0.5
MG_x_b_001 = np.load('MG_Pk_05_xb_0.01.npy')
MG_x_b_063 = np.load('MG_Pk_05_xb_0.63.npy')
MG_x_b_146 = np.load('MG_Pk_05_xb_1.46.npy')

#Varying x_m, x_b = 0.6, z = 0.5

MG_x_m_m03 = np.load('MG_Pk_05_xm_-0.3.npy')
MG_x_m_02 = np.load('MG_Pk_05_xm_0.2.npy')
MG_x_m_135 = np.load('MG_Pk_05_xm_1.35.npy')

# %%
# load values for P(k) at z = 3

fiducial_05 = np.load('LCDM_Pk_0.5.npy')
MG_best_fit_05 = np.load('mg_Pk_0.5.npy')

# Varying x_b, x_m = 0.2, z = 0.5
MG_x_b_001 = np.load('MG_Pk_05_xb_0.01.npy')
MG_x_b_063 = np.load('MG_Pk_05_xb_0.63.npy')
MG_x_b_146 = np.load('MG_Pk_05_xb_1.46.npy')

#Varying x_m, x_b = 0.6, z = 0.5

MG_x_m_m03 = np.load('MG_Pk_05_xm_-0.3.npy')
MG_x_m_02 = np.load('MG_Pk_05_xm_0.2.npy')
MG_x_m_135 = np.load('MG_Pk_05_xm_1.35.npy')

# %%
fiducial_3 = np.load('LCDM_Pk_3.npy')
MG_best_fit_3 = np.load('mg_Pk_3.npy')

# Varying x_b, x_m = 0.2, z = 0.5
MG_x_b_001_3 = np.load('MG_Pk_3_xb_0.01.npy')
#MG_x_b_063 = np.load('MG_Pk_05_xb_0.63.npy')
MG_x_b_146_3 = np.load('MG_Pk_3_xb_1.46.npy')

#Varying x_m, x_b = 0.6, z = 0.5

MG_x_m_m03_3 = np.load('MG_Pk_3_xm_-0.3.npy')
#MG_x_m_02 = np.load('MG_Pk_05_xm_0.2.npy')
MG_x_m_135_3 = np.load('MG_Pk_3_xm_1.35.npy')

# %%
plt.loglog(k, fiducial_05, '--', label = 'fiducial $\Lambda$CDM')
plt.loglog(k, MG_best_fit_05, label = 'best fit')

plt.loglog(k, MG_x_b_001, label = 'x_m = 0.2, x_b = 0.01')
#plt.loglog(k, MG_x_b_063, label = 'x_m = 0.2, x_b = 0.63')
plt.loglog(k, MG_x_b_146, label = 'x_m = 0.2, x_b = 1.46')

plt.legend()
plt.title('MG Varying x_b at z=0.5')
# Out:
# Text(0.5, 1.0, 'MG Varying x_b at z=0.5')

# %%
plt.loglog(k, fiducial_3, '--', label = 'fiducial $\Lambda$CDM')
plt.loglog(k, MG_best_fit_3, label = 'best fit')

plt.loglog(k, MG_x_b_001_3, label = 'x_m = 0.2, x_b = 0.01')
#plt.loglog(k, MG_x_b_063, label = 'x_m = 0.2, x_b = 0.63')
plt.loglog(k, MG_x_b_146_3, label = 'x_m = 0.2, x_b = 1.46')

plt.legend()
plt.title('MG Varying x_b at z=3')
# Out:
# Text(0.5, 1.0, 'MG Varying x_b at z=3')

# %%
plt.loglog(k, fiducial_05, '--', label = 'fiducial $\Lambda$CDM')
plt.loglog(k, MG_best_fit_05, label = 'best fit MG')

plt.loglog(k, MG_x_m_m03, label = 'x_m = -0.3, x_b = 0.6')
#plt.loglog(k, MG_x_m_02, label = 'x_m = 0.2, x_b = 0.6')
plt.loglog(k, MG_x_m_135, label = 'x_m = 1.35, x_b = 0.6')

plt.legend()
plt.title('MG Varying $x_m$ at z=0.5')
# Out:
# Text(0.5, 1.0, 'MG Varying $x_m$ at z=0.5')

# %%
plt.loglog(k, fiducial_3, '--', label = 'fiducial $\Lambda$CDM')
plt.loglog(k, MG_best_fit_3, label = 'best fit MG')

plt.loglog(k, MG_x_m_m03_3, label = 'x_m = -0.3, x_b = 0.6')
#plt.loglog(k, MG_x_m_02, label = 'x_m = 0.2, x_b = 0.6')
plt.loglog(k, MG_x_m_135_3, label = 'x_m = 1.35, x_b = 0.6')

plt.legend()
plt.title('MG Varying $x_m$ at z=3')
# Out:
# Text(0.5, 1.0, 'MG Varying $x_m$ at z=3')

# %%
plt.semilogx(k, (fiducial_3 - fiducial_3)/fiducial_3, '-', label = 'zero')
plt.semilogx(k, (MG_best_fit_3 - fiducial_3)/fiducial_3, label = 'best fit')
plt.semilogx(k, (MG_x_m_m03_3 - fiducial_3)/fiducial_3, label = 'x_m = -0.3, x_b = 0.6')
plt.semilogx(k, (MG_x_m_135_3 - fiducial_3)/fiducial_3, label = 'x_m = 1.35, x_b = 0.6')

plt.legend()
plt.title('Varying x_m, relative difference at z = 3')
plt.ylabel('relative difference')
plt.xlabel('k')
# Out:
# Text(0.5, 0, 'k')

# %%
plt.semilogx(k, (fiducial_05 - fiducial_05)/fiducial_05, '-', label = 'zero')
plt.semilogx(k, (MG_best_fit - fiducial_05)/fiducial_05, label = 'best fit')
plt.semilogx(k, (MG_x_m_m03 - fiducial_05)/fiducial_05, label = 'x_m = -0.3, x_b = 0.6')
plt.semilogx(k, (MG_x_m_135 - fiducial_05)/fiducial_05, label = 'x_m = 1.35, x_b = 0.6')

plt.legend()
plt.title('Varying x_m, relative difference at z = 0.5')
plt.ylabel('relative difference')
plt.xlabel('k')
# Out:
# Text(0.5, 0, 'k')

# %%
plt.semilogx(k, (fiducial_3 - fiducial_3)/fiducial_3, '-', label = 'zero')
plt.semilogx(k, (MG_best_fit_3 - fiducial_3)/fiducial_3, label = 'best fit')
plt.semilogx(k, (MG_x_b_001_3- fiducial_3)/fiducial_3, label = 'x_m = 0.2, x_b = 0.01')
plt.semilogx(k, (MG_x_b_146_3 - fiducial_3)/fiducial_3, label = 'x_m = 0.2, x_b = 1.46')

plt.legend()
plt.title('Varying x_b, relative difference at z = 3')
plt.ylabel('relative difference')
plt.xlabel('k')
# Out:
# Text(0.5, 0, 'k')

# %%
plt.semilogx(k, (fiducial_05 - fiducial_05)/fiducial_05, '-', label = 'zero')
plt.semilogx(k, (MG_best_fit_05 - fiducial_05)/fiducial_05, label = 'best fit')
plt.semilogx(k, (MG_x_b_001 - fiducial_05)/fiducial_05, label = 'x_m = 0.2, x_b = 0.01')
plt.semilogx(k, (MG_x_b_146 - fiducial_05)/fiducial_05, label = 'x_m = 0.2, x_b = 1.46')

plt.legend()
plt.title('Varying x_b, relative difference at z = 0.5')
plt.ylabel('relative difference')
plt.xlabel('k')
# Out:
# Text(0.5, 0, 'k')

# %%
# Now repeat for the Cls

# %%
cd Cls_from_hi_class/
# Out:
# /Users/bryan/Desktop/Research Summer 2020/Cls_from_hi_class

# %%
ls
# Out:
# LCDM_Cl_05.npy*                        MG_Cl_3_xm_1.3499999999999999.npy*
# LCDM_Cl_3.npy*                         MG_ell_05_xb_0.010000000000000009.npy*
# LCDM_ell_05.npy*                       MG_ell_05_xb_1.46.npy*
# LCDM_ell_3.npy*                        MG_ell_05_xm_-0.3.npy*
# MG_Cl_05_xb_0.010000000000000009.npy*  MG_ell_05_xm_1.3499999999999999.npy*
# MG_Cl_05_xb_1.46.npy*                  MG_ell_3.npy*
# MG_Cl_05_xm_-0.3.npy*                  MG_ell_3_xb_0.010000000000000009.npy*
# MG_Cl_05_xm_1.3499999999999999.npy*    MG_ell_3_xb_1.46.npy*
# MG_Cl_3_xb_0.010000000000000009.npy*   MG_ell_3_xm_-0.3.npy*
# MG_Cl_3_xb_1.46.npy*                   MG_ell_3_xm_1.3499999999999999.npy*
# MG_Cl_3_xm_-0.3.npy*                   Make_Cls.ipynb*

# %%
ell = np.load('LCDM_ell_05.npy')

# %%
fiducial_Cl_3 = np.load('LCDM_Cl_3.npy')
fiducial_Cl_05 = np.load('LCDM_Cl_05.npy')

# %%
#z = 3

#x_m = -0.3, x_b = 0.6

Cl_x_m_03_3 = np.load('MG_Cl_3_xm_-0.3.npy')

#x_m = 1.35, x_b = 0.6

Cl_x_m_135_3 = np.load('MG_Cl_3_xm_1.3499999999999999.npy')

plt.loglog(ell, Cl_x_m_03_3, label='x_m = -0.3, x_b = 0.6')
plt.loglog(ell, Cl_x_m_135_3, label='x_m = 1.35, x_b = 0.6')

#fiducial 
plt.loglog(ell, fiducial_Cl_3, '--', label = 'fiducial')
plt.legend()
plt.xlabel('l')
plt.ylabel('Cl')
plt.title('Varying x_m at z = 3')
# Out:
# Text(0.5, 1.0, 'Varying x_m at z = 3')

# %%
#z = 3

#x_m = -0.3, x_b = 0.6

Cl_x_m_03_3 = np.load('MG_Cl_3_xm_-0.3.npy')

#x_m = 1.35, x_b = 0.6

Cl_x_m_135_3 = np.load('MG_Cl_3_xm_1.3499999999999999.npy')

plt.loglog(ell, (Cl_x_m_03_3 - fiducial_Cl_3)/fiducial_Cl_3, label = 'x_m = -0.3, x_b = 0.6')
plt.title('Relative difference Cls at z = 3')
plt.xlabel('l')
plt.ylabel('Relative Difference')
plt.legend()
plt.show()

plt.loglog(ell, (Cl_x_m_135_3 - fiducial_Cl_3)/fiducial_Cl_3, label = 'x_m = 1.35, x_b = 0.6')
plt.title('Relative difference Cls at z = 3')
plt.xlabel('l')
plt.ylabel('Relative Difference')
plt.legend()
plt.show()


#fiducial 
#plt.loglog(ell, fiducial_Cl_3, '--')
# Out:
# <ipython-input-43-a2b197cada03>:11: RuntimeWarning: invalid value encountered in true_divide
#   plt.loglog(ell, (Cl_x_m_03_3 - fiducial_Cl_3)/fiducial_Cl_3, label = 'x_m = -0.3, x_b = 0.6')
# <ipython-input-43-a2b197cada03>:18: RuntimeWarning: invalid value encountered in true_divide
#   plt.loglog(ell, (Cl_x_m_135_3 - fiducial_Cl_3)/fiducial_Cl_3, label = 'x_m = 1.35, x_b = 0.6')

# %%
#x_m = 0.2 z = 3

Cl_x_b_001_3 = np.load('MG_Cl_3_xb_0.010000000000000009.npy')

#x_m = 0.2, x_b = 0.6

Cl_x_b_146_3 = np.load('MG_Cl_3_xb_1.46.npy')

plt.loglog(ell, Cl_x_b_001_3, label = 'x_b = 0.01 x_m = 0.2')
plt.loglog(ell, Cl_x_b_146_3, label = 'x_b = 1.46 x_m = 0.2')

#fiducial 
plt.loglog(ell, fiducial_Cl_3, '--', label = 'fiducial')
plt.legend()
plt.xlabel('l')
plt.ylabel('Cl')
plt.title('Varying x_b at z = 3')
# Out:
# Text(0.5, 1.0, 'Varying x_b at z = 3')

# %%
#x_m = 0.2, x_b = 0.6

Cl_x_b_001_3 = np.load('MG_Cl_3_xb_0.010000000000000009.npy')

#x_m = 0.2, x_b = 0.6

Cl_x_b_146_3 = np.load('MG_Cl_3_xb_1.46.npy')

plt.loglog(ell, (Cl_x_b_001_3 - fiducial_Cl_3)/fiducial_Cl_3, label = 'x_m = 0.2, x_b = 0.01')
plt.legend()
plt.xlabel('l')
plt.ylabel('relative difference')
plt.show()

plt.loglog(ell, (Cl_x_b_146_3 - fiducial_Cl_3)/fiducial_Cl_3, label = 'x_m = 0.2, x_b = 1.46')
plt.legend()
plt.xlabel('l')
plt.ylabel('relative difference')
plt.show()

#fiducial 
#plt.loglog(ell, fiducial_Cl_3, '--')
# Out:
# <ipython-input-47-0d3fc6a8b1a8>:9: RuntimeWarning: invalid value encountered in true_divide
#   plt.loglog(ell, (Cl_x_b_001_3 - fiducial_Cl_3)/fiducial_Cl_3, label = 'x_m = 0.2, x_b = 0.01')
# <ipython-input-47-0d3fc6a8b1a8>:15: RuntimeWarning: invalid value encountered in true_divide
#   plt.loglog(ell, (Cl_x_b_146_3 - fiducial_Cl_3)/fiducial_Cl_3, label = 'x_m = 0.2, x_b = 1.46')

# %%
#z = 0.5

#x_m = -0.3, x_b = 0.6

Cl_x_m_03_05 = np.load('MG_Cl_05_xm_-0.3.npy')

#x_m = 1.35, x_b = 0.6

Cl_x_m_135_05 = np.load('MG_Cl_05_xm_1.3499999999999999.npy')

plt.loglog(ell, Cl_x_m_03_05, label = 'x_m = -0.3, x_b = 0.6')
plt.loglog(ell, Cl_x_m_135_05, label = 'x_m = 1.35, x_b = 0.6')

#fiducial 
plt.loglog(ell, fiducial_Cl_05, '--', label = 'fiducial')
plt.xlabel('l')
plt.ylabel('Cl')
plt.title('Varying x_m at z = 0.5')
# Out:
# Text(0.5, 1.0, 'Varying x_m at z = 0.5')

# %%
#z = 0.5

#x_m = -0.3, x_b = 0.6

Cl_x_m_03_05 = np.load('MG_Cl_05_xm_-0.3.npy')

#x_m = 1.35, x_b = 0.6

Cl_x_m_135_05 = np.load('MG_Cl_05_xm_1.3499999999999999.npy')

plt.loglog(ell, (Cl_x_m_03_05-fiducial_Cl_05)/fiducial_Cl_05)
plt.show()
plt.loglog(ell, (Cl_x_m_135_05-fiducial_Cl_05)/fiducial_Cl_05)
plt.show()
#fiducial 
#plt.loglog(ell, fiducial_Cl_05, '--')
# Out:
# <ipython-input-35-644b8468bd23>:11: RuntimeWarning: invalid value encountered in true_divide
#   plt.loglog(ell, (Cl_x_m_03_05-fiducial_Cl_05)/fiducial_Cl_05)
# <ipython-input-35-644b8468bd23>:13: RuntimeWarning: invalid value encountered in true_divide
#   plt.loglog(ell, (Cl_x_m_135_05-fiducial_Cl_05)/fiducial_Cl_05)

# %%
#x_m = 0.2, x_b = 0.6

Cl_x_b_001_05 = np.load('MG_Cl_05_xb_0.010000000000000009.npy')

#x_m = 0.2, x_b = 0.6

Cl_x_b_146_05 = np.load('MG_Cl_05_xb_1.46.npy')

plt.loglog(ell, Cl_x_b_001_05, label = 'x_b = 0.01, x_m = 0.2')
plt.loglog(ell, Cl_x_b_146_05, label = 'x_b = 1.46, x_m = 0.2')

#fiducial 
plt.loglog(ell, fiducial_Cl_05, '--', label = 'fiducial')
plt.title('Varying x_b at redshift 0.5')
plt.xlabel('l')
plt.ylabel('Cl')
# Out:
# Text(0, 0.5, 'Cl')

# %%
#x_m = 0.2, x_b = 0.6

Cl_x_b_001_05 = np.load('MG_Cl_05_xb_0.010000000000000009.npy')

#x_m = 0.2, x_b = 0.6

Cl_x_b_146_05 = np.load('MG_Cl_05_xb_1.46.npy')

plt.loglog(ell, (Cl_x_b_001_05 - fiducial_Cl_05)/fiducial_Cl_05)
plt.show()
plt.loglog(ell, (Cl_x_b_146_05 - fiducial_Cl_05)/fiducial_Cl_05)
plt.show()

#fiducial 
#plt.loglog(ell, fiducial_Cl_05, '--')
# Out:
# <ipython-input-36-ab5fb1adcd46>:9: RuntimeWarning: invalid value encountered in true_divide
#   plt.loglog(ell, (Cl_x_b_001_05 - fiducial_Cl_05)/fiducial_Cl_05)
# <ipython-input-36-ab5fb1adcd46>:11: RuntimeWarning: invalid value encountered in true_divide
#   plt.loglog(ell, (Cl_x_b_146_05 - fiducial_Cl_05)/fiducial_Cl_05)
